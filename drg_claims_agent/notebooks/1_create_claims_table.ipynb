# %% [markdown]
# # DRG Claims Table Setup
#
# Run this notebook in Databricks to create the claims table and insert sample data.
# After this, create a **Genie Space** pointing to this table.

# %%
# %sql
# CREATE CATALOG IF NOT EXISTS healthcare;
# CREATE SCHEMA IF NOT EXISTS healthcare.claims;

# %%
# %sql
# CREATE TABLE IF NOT EXISTS healthcare.claims.drg_claims (
#     claim_id STRING,
#     patient_id STRING,
#     admission_date DATE,
#     discharge_date DATE,
#     drg_code STRING,
#     drg_description STRING,
#     principal_diagnosis STRING,
#     secondary_diagnoses ARRAY<STRING>,
#     procedures ARRAY<STRING>,
#     provider_id STRING,
#     provider_name STRING,
#     payer STRING,
#     total_charges DECIMAL(12,2),
#     total_payments DECIMAL(12,2),
#     length_of_stay INT,
#     discharge_status STRING,
#     readmission_flag BOOLEAN,
#     created_at TIMESTAMP
# );

# %%
# %sql
# INSERT INTO healthcare.claims.drg_claims VALUES
# -- MS-DRG 470: Major Hip and Knee Joint Replacement
# ('CLM001','PAT101','2025-01-05','2025-01-08','470','Major Hip and Knee Joint Replacement Without MCC','M16.11',array('E11.9','I10'),array('0SR9019'),'PRV01','City General Hospital','Medicare',85200.00,32500.00,3,'Home',false,current_timestamp()),
# ('CLM002','PAT102','2025-01-12','2025-01-15','470','Major Hip and Knee Joint Replacement Without MCC','M17.11',array('I10','Z87.39'),array('0SRC019'),'PRV01','City General Hospital','Medicare',92100.00,33800.00,3,'Home',false,current_timestamp()),
# ('CLM003','PAT103','2025-01-20','2025-01-24','470','Major Hip and Knee Joint Replacement Without MCC','M16.12',array('E78.5'),array('0SR9019'),'PRV02','Regional Medical Center','BlueCross',88500.00,45200.00,4,'Home',false,current_timestamp()),
# ('CLM004','PAT104','2025-02-02','2025-02-06','470','Major Hip and Knee Joint Replacement Without MCC','M17.12',array('I10','E11.65'),array('0SRC019'),'PRV02','Regional Medical Center','Aetna',91000.00,41000.00,4,'SNF',true,current_timestamp()),
# ('CLM005','PAT105','2025-02-14','2025-02-16','470','Major Hip and Knee Joint Replacement Without MCC','M16.11',array(),array('0SR9019'),'PRV03','University Hospital','UnitedHealth',79800.00,35600.00,2,'Home',false,current_timestamp()),
# ('CLM006','PAT106','2025-03-01','2025-03-05','470','Major Hip and Knee Joint Replacement Without MCC','M17.11',array('I10','J44.1'),array('0SRC019'),'PRV01','City General Hospital','Medicare',95300.00,34200.00,4,'Home',false,current_timestamp()),
# ('CLM007','PAT107','2025-03-10','2025-03-14','470','Major Hip and Knee Joint Replacement Without MCC','M16.9',array('E11.9','I25.10'),array('0SR9019'),'PRV03','University Hospital','Cigna',102000.00,48500.00,4,'Rehab',true,current_timestamp()),
#
# -- MS-DRG 871: Septicemia or Severe Sepsis Without MV >96 Hours With MCC
# ('CLM008','PAT108','2025-01-08','2025-01-15','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.9',array('R65.20','N17.9','J96.01'),array(),'PRV01','City General Hospital','Medicare',125000.00,52000.00,7,'Home',false,current_timestamp()),
# ('CLM009','PAT109','2025-01-22','2025-02-02','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.01',array('R65.21','J18.9','N17.9'),array(),'PRV02','Regional Medical Center','Medicaid',142000.00,48000.00,11,'SNF',true,current_timestamp()),
# ('CLM010','PAT110','2025-02-05','2025-02-12','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.9',array('R65.20','E11.65','I50.9'),array(),'PRV03','University Hospital','Medicare',118500.00,51500.00,7,'Home',false,current_timestamp()),
# ('CLM011','PAT111','2025-02-18','2025-02-28','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.02',array('R65.21','J96.01','N17.9','D69.6'),array(),'PRV01','City General Hospital','BlueCross',168000.00,72000.00,10,'LTAC',false,current_timestamp()),
# ('CLM012','PAT112','2025-03-05','2025-03-11','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.9',array('R65.20','J18.1'),array(),'PRV02','Regional Medical Center','Medicare',112000.00,49800.00,6,'Home',true,current_timestamp()),
# ('CLM013','PAT113','2025-03-20','2025-03-30','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.01',array('R65.21','N17.9','G93.41'),array(),'PRV03','University Hospital','Aetna',195000.00,85000.00,10,'Expired',false,current_timestamp()),
#
# -- MS-DRG 392: Esophagitis, Gastroenteritis and Miscellaneous Digestive Disorders Without MCC
# ('CLM014','PAT114','2025-01-10','2025-01-12','392','Esophagitis Gastroent and Misc Digestive Disorders Without MCC','K21.0',array('K44.9'),array(),'PRV01','City General Hospital','UnitedHealth',28500.00,12800.00,2,'Home',false,current_timestamp()),
# ('CLM015','PAT115','2025-01-25','2025-01-27','392','Esophagitis Gastroent and Misc Digestive Disorders Without MCC','K52.9',array('E11.9'),array(),'PRV02','Regional Medical Center','Cigna',32100.00,14500.00,2,'Home',false,current_timestamp()),
# ('CLM016','PAT116','2025-02-08','2025-02-10','392','Esophagitis Gastroent and Misc Digestive Disorders Without MCC','K21.0',array(),array(),'PRV01','City General Hospital','Medicare',26800.00,11200.00,2,'Home',false,current_timestamp()),
# ('CLM017','PAT117','2025-02-22','2025-02-25','392','Esophagitis Gastroent and Misc Digestive Disorders Without MCC','K29.70',array('K44.9','I10'),array(),'PRV03','University Hospital','BlueCross',35200.00,16800.00,3,'Home',false,current_timestamp()),
# ('CLM018','PAT118','2025-03-12','2025-03-14','392','Esophagitis Gastroent and Misc Digestive Disorders Without MCC','K52.9',array('E78.5'),array(),'PRV02','Regional Medical Center','Medicaid',29400.00,10500.00,2,'Home',false,current_timestamp()),
#
# -- MS-DRG 291: Heart Failure and Shock With MCC
# ('CLM019','PAT119','2025-01-15','2025-01-20','291','Heart Failure and Shock With MCC','I50.23',array('I13.0','N18.4','E11.65'),array(),'PRV01','City General Hospital','Medicare',78500.00,35200.00,5,'Home',false,current_timestamp()),
# ('CLM020','PAT120','2025-01-28','2025-02-04','291','Heart Failure and Shock With MCC','I50.33',array('I13.2','J81.0','N17.9'),array(),'PRV02','Regional Medical Center','Medicare',95200.00,41000.00,7,'SNF',true,current_timestamp()),
# ('CLM021','PAT121','2025-02-10','2025-02-16','291','Heart Failure and Shock With MCC','I50.43',array('I48.91','I25.10','E11.9'),array(),'PRV03','University Hospital','Aetna',82100.00,45500.00,6,'Home',false,current_timestamp()),
# ('CLM022','PAT122','2025-02-25','2025-03-05','291','Heart Failure and Shock With MCC','I50.23',array('I13.0','N18.6','E87.1'),array(),'PRV01','City General Hospital','BlueCross',112000.00,52000.00,8,'LTAC',false,current_timestamp()),
# ('CLM023','PAT123','2025-03-08','2025-03-14','291','Heart Failure and Shock With MCC','I50.9',array('I10','J81.0'),array(),'PRV02','Regional Medical Center','UnitedHealth',76800.00,38500.00,6,'Home',true,current_timestamp()),
#
# -- MS-DRG 690: Kidney and Urinary Tract Infections Without MCC
# ('CLM024','PAT124','2025-01-03','2025-01-06','690','Kidney and Urinary Tract Infections Without MCC','N39.0',array('E11.9'),array(),'PRV01','City General Hospital','Cigna',22500.00,9800.00,3,'Home',false,current_timestamp()),
# ('CLM025','PAT125','2025-01-18','2025-01-20','690','Kidney and Urinary Tract Infections Without MCC','N10',array('N20.0'),array(),'PRV02','Regional Medical Center','Medicare',25100.00,10500.00,2,'Home',false,current_timestamp()),
# ('CLM026','PAT126','2025-02-01','2025-02-04','690','Kidney and Urinary Tract Infections Without MCC','N39.0',array('I10','E78.5'),array(),'PRV03','University Hospital','BlueCross',28200.00,13200.00,3,'Home',false,current_timestamp()),
# ('CLM027','PAT127','2025-02-15','2025-02-18','690','Kidney and Urinary Tract Infections Without MCC','N10',array(),array(),'PRV01','City General Hospital','Medicaid',21800.00,8500.00,3,'Home',false,current_timestamp()),
# ('CLM028','PAT128','2025-03-02','2025-03-04','690','Kidney and Urinary Tract Infections Without MCC','N39.0',array('E11.65'),array(),'PRV02','Regional Medical Center','Aetna',24500.00,11800.00,2,'Home',true,current_timestamp()),
#
# -- MS-DRG 193: Simple Pneumonia and Pleurisy With MCC
# ('CLM029','PAT129','2025-01-06','2025-01-12','193','Simple Pneumonia and Pleurisy With MCC','J18.9',array('J96.01','E11.65','I50.9'),array(),'PRV01','City General Hospital','Medicare',68500.00,32000.00,6,'Home',false,current_timestamp()),
# ('CLM030','PAT130','2025-01-20','2025-01-28','193','Simple Pneumonia and Pleurisy With MCC','J15.9',array('J96.01','N17.9','I48.91'),array(),'PRV02','Regional Medical Center','Medicare',85200.00,38500.00,8,'SNF',true,current_timestamp()),
# ('CLM031','PAT131','2025-02-04','2025-02-10','193','Simple Pneumonia and Pleurisy With MCC','J18.1',array('J44.1','I10'),array(),'PRV03','University Hospital','UnitedHealth',72100.00,35800.00,6,'Home',false,current_timestamp()),
# ('CLM032','PAT132','2025-02-20','2025-02-26','193','Simple Pneumonia and Pleurisy With MCC','J15.1',array('E11.9','I25.10','N18.3'),array(),'PRV01','City General Hospital','Cigna',78900.00,42000.00,6,'Home',false,current_timestamp()),
# ('CLM033','PAT133','2025-03-15','2025-03-24','193','Simple Pneumonia and Pleurisy With MCC','J18.9',array('J96.01','G93.41','N17.9'),array(),'PRV02','Regional Medical Center','Aetna',125000.00,55000.00,9,'Expired',false,current_timestamp()),
#
# -- MS-DRG 065: Intracranial Hemorrhage or Cerebral Infarction With MCC
# ('CLM034','PAT134','2025-01-09','2025-01-16','064','Intracranial Hemorrhage or Cerebral Infarction With MCC','I63.9',array('I10','I48.91','E11.9'),array(),'PRV03','University Hospital','Medicare',92000.00,42500.00,7,'Rehab',false,current_timestamp()),
# ('CLM035','PAT135','2025-02-03','2025-02-12','064','Intracranial Hemorrhage or Cerebral Infarction With MCC','I61.9',array('I10','E11.65','G93.41'),array(),'PRV01','City General Hospital','BlueCross',145000.00,65000.00,9,'SNF',false,current_timestamp()),
# ('CLM036','PAT136','2025-03-01','2025-03-08','064','Intracranial Hemorrhage or Cerebral Infarction With MCC','I63.50',array('I10','I48.0'),array('03CG3ZZ'),'PRV02','Regional Medical Center','Medicare',108000.00,48000.00,7,'Rehab',true,current_timestamp()),
#
# -- MS-DRG 247: Percutaneous Cardiovascular Procedures With Drug-Eluting Stent Without MCC
# ('CLM037','PAT137','2025-01-14','2025-01-16','247','Perc Cardiovasc Proc With Drug-Eluting Stent Without MCC','I25.10',array('I10','E78.5'),array('02703DZ'),'PRV01','City General Hospital','BlueCross',62500.00,28500.00,2,'Home',false,current_timestamp()),
# ('CLM038','PAT138','2025-02-06','2025-02-08','247','Perc Cardiovasc Proc With Drug-Eluting Stent Without MCC','I25.10',array('E11.9','I10'),array('02703DZ'),'PRV03','University Hospital','Aetna',58900.00,31200.00,2,'Home',false,current_timestamp()),
# ('CLM039','PAT139','2025-03-11','2025-03-13','247','Perc Cardiovasc Proc With Drug-Eluting Stent Without MCC','I25.110',array('I10'),array('02703DZ'),'PRV02','Regional Medical Center','Medicare',55200.00,25800.00,2,'Home',false,current_timestamp()),
#
# -- MS-DRG 885: Psychoses
# ('CLM040','PAT140','2025-01-02','2025-01-09','885','Psychoses','F20.9',array(),array(),'PRV04','Behavioral Health Center','Medicaid',18500.00,8200.00,7,'Home',false,current_timestamp()),
# ('CLM041','PAT141','2025-01-20','2025-02-01','885','Psychoses','F31.9',array('F10.20'),array(),'PRV04','Behavioral Health Center','Medicare',24200.00,10500.00,12,'Group Home',false,current_timestamp()),
# ('CLM042','PAT142','2025-02-10','2025-02-20','885','Psychoses','F25.9',array(),array(),'PRV04','Behavioral Health Center','BlueCross',21800.00,11200.00,10,'Home',true,current_timestamp()),
#
# -- Intentional coding mismatches for audit testing
# ('CLM043','PAT143','2025-01-30','2025-02-02','470','Major Hip and Knee Joint Replacement Without MCC','J18.9',array(),array('0SR9019'),'PRV01','City General Hospital','Medicare',87000.00,33000.00,3,'Home',false,current_timestamp()),
# ('CLM044','PAT144','2025-02-12','2025-02-18','291','Heart Failure and Shock With MCC','M17.11',array('I10'),array(),'PRV02','Regional Medical Center','Aetna',82000.00,38000.00,6,'Home',false,current_timestamp()),
# ('CLM045','PAT145','2025-03-05','2025-03-08','690','Kidney and Urinary Tract Infections Without MCC','I50.23',array(),array(),'PRV03','University Hospital','Cigna',25000.00,11000.00,3,'Home',false,current_timestamp()),
#
# -- Q2 data for trend analysis
# ('CLM046','PAT146','2025-04-02','2025-04-05','470','Major Hip and Knee Joint Replacement Without MCC','M16.11',array('I10'),array('0SR9019'),'PRV01','City General Hospital','Medicare',88500.00,33500.00,3,'Home',false,current_timestamp()),
# ('CLM047','PAT147','2025-04-15','2025-04-22','871','Septicemia or Severe Sepsis Without MV >96 Hours With MCC','A41.9',array('R65.20','N17.9'),array(),'PRV02','Regional Medical Center','Medicare',130000.00,53000.00,7,'Home',true,current_timestamp()),
# ('CLM048','PAT148','2025-05-01','2025-05-03','392','Esophagitis Gastroent and Misc Digestive Disorders Without MCC','K21.0',array(),array(),'PRV03','University Hospital','BlueCross',27500.00,12000.00,2,'Home',false,current_timestamp()),
# ('CLM049','PAT149','2025-05-10','2025-05-16','291','Heart Failure and Shock With MCC','I50.23',array('I13.0','N18.4'),array(),'PRV01','City General Hospital','UnitedHealth',81000.00,36500.00,6,'Home',false,current_timestamp()),
# ('CLM050','PAT150','2025-06-01','2025-06-04','690','Kidney and Urinary Tract Infections Without MCC','N39.0',array('E11.9'),array(),'PRV02','Regional Medical Center','Aetna',23500.00,10200.00,3,'Home',false,current_timestamp());

# %%
# %sql
# -- DRG SHIFT DATA: Heart Failure -- City General heavily favors MCC (DRG 291)
# INSERT INTO healthcare.claims.drg_claims VALUES
# ('CLM060','PAT160','2025-04-05','2025-04-11','291','Heart Failure and Shock With MCC','I50.33',array('I13.0','N18.4','E11.65'),array(),'PRV01','City General Hospital','Medicare',85000.00,37000.00,6,'Home',false,current_timestamp()),
# ('CLM061','PAT161','2025-04-18','2025-04-24','291','Heart Failure and Shock With MCC','I50.23',array('I13.2','J81.0'),array(),'PRV01','City General Hospital','BlueCross',91000.00,42000.00,6,'SNF',false,current_timestamp()),
# ('CLM062','PAT162','2025-05-02','2025-05-06','292','Heart Failure and Shock With CC','I50.9',array('I10','E78.5'),array(),'PRV01','City General Hospital','Aetna',62000.00,28000.00,4,'Home',false,current_timestamp()),
# ('CLM063','PAT163','2025-05-15','2025-05-21','291','Heart Failure and Shock With MCC','I50.43',array('I48.91','N17.9','E11.9'),array(),'PRV01','City General Hospital','Medicare',95000.00,41000.00,6,'Home',false,current_timestamp()),
# ('CLM064','PAT164','2025-06-01','2025-06-04','293','Heart Failure and Shock Without CC/MCC','I50.9',array(),array(),'PRV01','City General Hospital','UnitedHealth',42000.00,18000.00,3,'Home',false,current_timestamp()),
#
# -- DRG SHIFT DATA: Heart Failure -- Regional Medical more balanced/conservative
# ('CLM065','PAT165','2025-04-08','2025-04-13','292','Heart Failure and Shock With CC','I50.23',array('I10','E78.5'),array(),'PRV02','Regional Medical Center','Medicare',58000.00,26000.00,5,'Home',false,current_timestamp()),
# ('CLM066','PAT166','2025-04-22','2025-04-27','292','Heart Failure and Shock With CC','I50.33',array('I10','E11.9'),array(),'PRV02','Regional Medical Center','Cigna',61000.00,29000.00,5,'Home',false,current_timestamp()),
# ('CLM067','PAT167','2025-05-05','2025-05-08','293','Heart Failure and Shock Without CC/MCC','I50.9',array(),array(),'PRV02','Regional Medical Center','Medicaid',38000.00,15000.00,3,'Home',false,current_timestamp()),
# ('CLM068','PAT168','2025-05-20','2025-05-25','292','Heart Failure and Shock With CC','I50.43',array('I10','I48.91'),array(),'PRV02','Regional Medical Center','BlueCross',64000.00,30000.00,5,'Home',false,current_timestamp()),
# ('CLM069','PAT169','2025-06-03','2025-06-06','293','Heart Failure and Shock Without CC/MCC','I50.9',array('I10'),array(),'PRV02','Regional Medical Center','Aetna',40000.00,17000.00,3,'Home',false,current_timestamp()),
#
# -- DRG SHIFT DATA: Heart Failure -- University Hospital moderate
# ('CLM070','PAT170','2025-04-12','2025-04-17','292','Heart Failure and Shock With CC','I50.23',array('I10','E78.5'),array(),'PRV03','University Hospital','Medicare',65000.00,32000.00,5,'Home',false,current_timestamp()),
# ('CLM071','PAT171','2025-05-08','2025-05-14','291','Heart Failure and Shock With MCC','I50.33',array('I13.0','N18.4','J81.0'),array(),'PRV03','University Hospital','Aetna',88000.00,44000.00,6,'SNF',true,current_timestamp()),
# ('CLM072','PAT172','2025-05-25','2025-05-28','293','Heart Failure and Shock Without CC/MCC','I50.9',array(),array(),'PRV03','University Hospital','BlueCross',41000.00,19000.00,3,'Home',false,current_timestamp()),
# ('CLM073','PAT173','2025-06-10','2025-06-15','292','Heart Failure and Shock With CC','I50.23',array('I10','E11.9'),array(),'PRV03','University Hospital','UnitedHealth',63000.00,31000.00,5,'Home',false,current_timestamp()),
#
# -- DRG SHIFT DATA: Pneumonia -- City General heavily MCC
# ('CLM074','PAT174','2025-04-03','2025-04-09','193','Simple Pneumonia and Pleurisy With MCC','J18.9',array('J96.01','E11.65'),array(),'PRV01','City General Hospital','Medicare',72000.00,34000.00,6,'Home',false,current_timestamp()),
# ('CLM075','PAT175','2025-05-10','2025-05-16','193','Simple Pneumonia and Pleurisy With MCC','J15.9',array('J96.01','N17.9'),array(),'PRV01','City General Hospital','BlueCross',78000.00,38000.00,6,'Home',false,current_timestamp()),
# ('CLM076','PAT176','2025-06-05','2025-06-09','194','Simple Pneumonia and Pleurisy With CC','J18.1',array('J44.1'),array(),'PRV01','City General Hospital','Aetna',48000.00,22000.00,4,'Home',false,current_timestamp()),
#
# -- DRG SHIFT DATA: Pneumonia -- Regional Medical more conservative
# ('CLM077','PAT177','2025-04-15','2025-04-19','194','Simple Pneumonia and Pleurisy With CC','J18.9',array('I10','E78.5'),array(),'PRV02','Regional Medical Center','Medicare',52000.00,24000.00,4,'Home',false,current_timestamp()),
# ('CLM078','PAT178','2025-05-20','2025-05-24','194','Simple Pneumonia and Pleurisy With CC','J15.1',array('E11.9'),array(),'PRV02','Regional Medical Center','Cigna',49000.00,23000.00,4,'Home',false,current_timestamp()),
# ('CLM079','PAT179','2025-06-08','2025-06-10','195','Simple Pneumonia and Pleurisy Without CC/MCC','J18.1',array(),array(),'PRV02','Regional Medical Center','Medicaid',32000.00,14000.00,2,'Home',false,current_timestamp()),
#
# -- DRG SHIFT DATA: Pneumonia -- University Hospital balanced
# ('CLM080','PAT180','2025-04-20','2025-04-24','194','Simple Pneumonia and Pleurisy With CC','J18.9',array('I10','J44.1'),array(),'PRV03','University Hospital','Aetna',55000.00,27000.00,4,'Home',false,current_timestamp()),
# ('CLM081','PAT181','2025-05-15','2025-05-19','194','Simple Pneumonia and Pleurisy With CC','J15.9',array('E11.9'),array(),'PRV03','University Hospital','UnitedHealth',51000.00,25000.00,4,'Home',false,current_timestamp()),
# ('CLM082','PAT182','2025-06-12','2025-06-14','195','Simple Pneumonia and Pleurisy Without CC/MCC','J18.9',array(),array(),'PRV03','University Hospital','BlueCross',30000.00,13000.00,2,'Home',false,current_timestamp()),
#
# -- DRG SHIFT DATA: Sepsis -- City General all MCC, others mixed
# ('CLM083','PAT183','2025-04-10','2025-04-17','871','Septicemia or Severe Sepsis With MCC','A41.9',array('R65.20','N17.9','J96.01'),array(),'PRV01','City General Hospital','Medicare',135000.00,55000.00,7,'Home',false,current_timestamp()),
# ('CLM084','PAT184','2025-05-18','2025-05-25','871','Septicemia or Severe Sepsis With MCC','A41.01',array('R65.21','N17.9'),array(),'PRV01','City General Hospital','BlueCross',142000.00,60000.00,7,'SNF',false,current_timestamp()),
# ('CLM085','PAT185','2025-04-25','2025-04-30','872','Septicemia or Severe Sepsis Without MCC','A41.9',array('R65.20'),array(),'PRV02','Regional Medical Center','Medicaid',75000.00,32000.00,5,'Home',false,current_timestamp()),
# ('CLM086','PAT186','2025-05-10','2025-05-15','872','Septicemia or Severe Sepsis Without MCC','A41.9',array('R65.20','I10'),array(),'PRV03','University Hospital','Medicare',78000.00,34000.00,5,'Home',false,current_timestamp()),
# ('CLM087','PAT187','2025-06-01','2025-06-06','872','Septicemia or Severe Sepsis Without MCC','A41.02',array('R65.20'),array(),'PRV03','University Hospital','Aetna',72000.00,31000.00,5,'Home',false,current_timestamp());

# %% [markdown]
# ## Next Steps
#
# After running this notebook:
# 1. Go to **Genie > Create Space**
# 2. Add `healthcare.claims.drg_claims` table
# 3. Set instructions: *"This table contains hospital inpatient claims with DRG codes, ICD-10 diagnoses, charges, payments, and length of stay. Use it to analyze costs, readmissions, coding patterns, and provider performance."*
# 4. Note the **Space ID** from the URL and put it in your `.env` file
